# %%
# ALl imports
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

pd.set_option("display.max_rows", None, "display.max_columns", None)
df = pd.read_csv('datasets/Project_Dataset.csv')
#df.shape

# %%
#df = df.sample(frac=0.5, replace=False, random_state=42)
#df.shape

# %%
categorical_list = pd.read_csv('datasets/VehiclesInformation.csv').columns.tolist()
numerical_list = pd.read_csv('datasets/Measurments_in_SENDTIME.csv').columns.tolist()

# Jespers adaption to categorical_df and numerical values
#float_cols = [key for key,val in df.dtypes.items() if val == 'float64']
#int_cols = [key for key,val in data.dtypes.items() if val == 'int64']
#not_float_cols = [key for key in float_cols if sum(data[key].apply(lambda i:i.is_integer())) == sum(~data[key].isna())]
#float_cols = [col for col in float_cols if col not in not_float_cols]

# %%
df.describe()
# Out:
#           Sample_ID  Charge_mode_DISTANCE     Vehicle_ID  Operation_TIME  \
# count  8.619160e+05              238078.0  861916.000000   861815.000000
# mean   1.605535e+08                   0.0     914.695734     8950.790168
# std    1.040139e+08                   0.0     907.401415     5888.556969
# min    1.673760e+06                   0.0       1.000000        0.000000
# 25%    6.912538e+07                   0.0     252.000000     4008.835000
# 50%    1.428708e+08                   0.0     584.000000     8343.850000
# 75%    2.409448e+08                   0.0    1258.000000    13529.176000
# max    4.053350e+08                   0.0    4031.000000   192780.000000
#
#        Operation_DISTANCE         Sender  Gear_Level_Auto_Time  \
# count       826697.000000  861916.000000         109882.000000
# mean        168684.138197       1.833639           6954.796127
# std         106473.041228       0.477447           6005.307955
# min              0.000000       1.000000              0.000000
# 25%          81337.060000       2.000000           1873.763750
# 50%         157989.780000       2.000000           5633.414500
# 75%         249276.010000       2.000000          10676.468000
# max         788407.110000       4.000000          32457.343000
#
#        Gear_Level_Man_Time  Total_Distance     Brake_Time    Cruise_Time  \
# count         109906.00000   798851.000000  278583.000000  202469.000000
# mean               0.02447   168093.327635      93.198303       2.318812
# std                2.41849   105243.858682     954.888471     677.038889
# min                0.00000        0.000000       0.000000       0.000000
# 25%                0.00000    81626.920000      15.503000       0.000000
# 50%                0.00000   157211.620000      52.308000       0.000000
# 75%                0.00000   247597.754000     125.230000       0.000000
# max              507.93500   764774.113000  291985.930000  304424.812000
#
#        Drive_Distance    Drive_Fuel     Drive_Time      Idle_Fuel  \
# count   506445.000000  5.032910e+05  536956.000000  503274.000000
# mean    155092.674399  2.249406e+05    5370.606848   16964.597799
# std     105134.455727  1.445176e+05    3587.547315   17560.201651
# min          0.000000  0.000000e+00       0.000000       0.000000
# 25%      70307.430000  1.097098e+05    2584.632000    5590.238177
# 50%     143138.200000  2.138548e+05    4927.625000   11336.013148
# 75%     223082.700000  3.220442e+05    7605.552750   22893.769017
# max     764718.163000  1.232502e+06   22146.233000  171566.915674
#
#        Coasting_Time      Econ_Time      Idle_Time    Key_On_Time  \
# count  181441.000000  161594.000000  788100.000000  532004.000000
# mean     1178.372773    2942.647370    2422.450477    9982.880151
# std       985.907388    2673.787443    2104.067300    6492.809635
# min         0.000000       0.000000       0.000000       0.000000
# 25%       344.389000     779.869250     720.820750    4843.980500
# 50%       985.303000    2304.863500    1647.719000    9358.866500
# 75%      1815.603000    4342.594750    3898.171000   14077.433000
# max     61877.590000   13867.866000   15559.693000   42411.382000
#
#           Pedal_Time      measure35      measure36      measure37  \
# count  181251.000000  202294.000000  181269.000000  161567.000000
# mean     1569.209152       0.051096      46.385956     615.662478
# std      1314.868734      13.441627      88.894753    1024.787936
# min         0.000000       0.000000       0.000000       0.000000
# 25%       492.956500       0.000000       6.969000     173.570000
# 50%      1309.825000       0.000000      13.993000     468.230000
# 75%      2310.474000       0.000000      42.710000     910.619500
# max      7322.293000    3856.097000    2209.159000  347282.627000
#
#            measure38      measure39      measure40      measure41  \
# count  424111.000000  427152.000000  133646.000000  661906.000000
# mean        0.901495    7573.258953       9.649170  169547.478055
# std        23.071409    6860.789614     191.788297  106832.459806
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000    3061.171000       0.000000   81630.538250
# 50%         0.030000    6193.440500       0.000000  159414.126000
# 75%         0.562000   10641.270250       1.000000  252041.508500
# max      2622.680000  112277.085000   10031.000000  726090.460000
#
#            measure42      measure43      measure44      measure45  \
# count  661922.000000  465493.000000  473534.000000  445570.000000
# mean       61.481415    6781.350173    4809.420994       9.675092
# std       129.885507    4535.185180    3429.560190      14.701637
# min         0.000000       0.000000       0.000000       0.000000
# 25%         5.938000    3129.580000    2159.703250       2.236000
# 50%        21.600000    6306.487000    4339.351000       5.131000
# 75%        64.650000    9765.446000    6726.851750      10.986000
# max      3685.364000   28728.241000   25635.787000     279.554000
#
#            measure46      measure47      measure48      measure49  \
# count  467305.000000  467216.000000  465362.000000  467094.000000
# mean     2333.207444       0.275380    1476.301991      25.018116
# std      1594.781897       2.416467    1208.234013      29.612928
# min         0.000000       0.000000       0.000000       0.000000
# 25%      1029.693000       0.000000     588.476500       6.498000
# 50%      2127.719000       0.058000    1183.194500      15.084000
# 75%      3416.858000       0.263000    2044.127750      32.533000
# max     10952.104000     244.157000    9397.937000     354.896000
#
#        Measure_G-1_Time  State_Of_Health_Battery  Diesel_Mode_Total_Fuel  \
# count      1.612370e+05            213860.000000           225385.000000
# mean       9.916824e+02                82.849888              211.315261
# std        9.885296e+03                13.765894              352.474578
# min        0.000000e+00                 0.000000                0.000000
# 25%        1.615510e+02                75.000000               46.613335
# 50%        5.356490e+02                83.750000              102.085929
# 75%        1.114614e+03                95.000000              227.978278
# max        1.193056e+06               100.000000             7801.282187
#
#            measure50     measure51     Measure_3  Electric_Mode_Time  \
# count  271163.000000  2.656360e+05  3.006480e+05        6.545090e+05
# mean     2916.653578  2.188812e+03  2.200109e+06        2.559039e+03
# std      2162.156577  2.528516e+03  1.608684e+06        2.062436e+03
# min         0.000000  0.000000e+00  0.000000e+00        0.000000e+00
# 25%      1895.800000  1.624609e+03  9.987885e+05        1.561799e+03
# 50%      2409.380000  2.172645e+03  1.919658e+06        2.383418e+03
# 75%      3044.360000  2.685043e+03  3.157862e+06        3.353565e+03
# max     46076.949000  1.193056e+06  1.518202e+07        1.193056e+06
#
#        Hybrid_Mode_Time  Charge_Mode_Time  Diesel_Mode_Time    Total_Time  \
# count     654104.000000      6.544760e+05      6.329780e+05  6.309890e+05
# mean        9380.684591      3.872595e+01      1.705938e+01  1.219556e+04
# std         5624.617100      1.475055e+03      1.499661e+03  7.896164e+03
# min            0.000000     -1.001667e+00     -4.833333e-02  0.000000e+00
# 25%         4990.595556      1.159542e+01      4.514042e+00  7.351574e+03
# 50%         8548.220972      2.774400e+01      9.306833e+00  1.204531e+04
# 75%        13940.667000      5.572014e+01      1.824222e+01  1.738936e+04
# max        35702.002000      1.193056e+06      1.193056e+06  3.598838e+06
#
#        Electric_Mode_Distance  Hybrid_Mode_Distance  Diesel_Mode_Distance  \
# count           617031.000000         659976.000000         660637.000000
# mean              6799.205918         186747.229050             68.730186
# std               6854.103732         104558.643889            148.490047
# min                  0.000000              0.000000             -0.387000
# 25%               2345.485500         105004.893000              7.860000
# 50%               4386.514000         181769.258500             24.628000
# 75%               9629.709000         266621.956500             70.045000
# max             116664.986000         726090.460000           3685.364000
#
#        Total_Distance__ElectricHybridDiesel  Battery_Version  \
# count                         615662.000000    861916.000000
# mean                          196896.154366         0.102657
# std                           105712.507731         0.321870
# min                                0.000000         0.000000
# 25%                           114511.133500         0.000000
# 50%                           194199.651000         0.000000
# 75%                           277398.044250         0.000000
# max                           734290.120000         4.000000
#
#        Battery_Generation       Fleet_ID        Country  Vehicle_MRK_TYPE  \
# count       836463.000000  723818.000000  861915.000000     861916.000000
# mean             1.746087      54.372580       4.280604          2.733117
# std              1.073060      52.836068       4.214571          1.601607
# min              1.000000       1.000000       1.000000          1.000000
# 25%              1.000000      15.000000       1.000000          2.000000
# 50%              1.000000      40.000000       2.000000          2.000000
# 75%              3.000000      70.000000       5.000000          3.000000
# max              6.000000     296.000000      27.000000          9.000000
#
#        EMISSION_LEVEL  CURRENT_YEARLY_MILEAGE      Measure_2  Active_Charge  \
# count   861916.000000            861916.00000  646879.000000   29631.000000
# mean         1.330508                 5.07670       1.085858       1.018157
# std          0.470396                 4.04253       0.280155       0.133520
# min          1.000000                 1.00000       1.000000       1.000000
# 25%          1.000000                 3.00000       1.000000       1.000000
# 50%          1.000000                 4.00000       1.000000       1.000000
# 75%          2.000000                 5.00000       1.000000       1.000000
# max          2.000000                33.00000       2.000000       2.000000
#
#        Mounted_Battery_Generation      Measure_1    Measure_R_D  \
# count               861837.000000  750973.000000  774348.000000
# mean                     1.700433       3.177602      11.733245
# std                      0.979034       2.856095      15.647778
# min                      1.000000       1.000000       1.000000
# 25%                      1.000000       1.000000       4.000000
# 50%                      1.000000       2.000000       5.000000
# 75%                      3.000000       6.000000      11.000000
# max                      6.000000      21.000000     115.000000
#
#          Engine_Type       Geo_Area           City        Cluster  \
# count  725789.000000  724928.000000  713059.000000  568613.000000
# mean        1.392464       1.224586      14.587535       2.591699
# std         0.488367       0.806776      18.446428       1.489970
# min         1.000000       1.000000       1.000000       1.000000
# 25%         1.000000       1.000000       3.000000       1.000000
# 50%         1.000000       1.000000       5.000000       2.000000
# 75%         2.000000       1.000000      21.000000       4.000000
# max         4.000000       8.000000     124.000000       8.000000
#
#          Measure_ROw  Is_Bttery_Changed  IS_PATTERN_AVAILABLE  \
# count  861916.000000      861916.000000         861916.000000
# mean     2017.983685           0.195157              0.047081
# std      1375.534256           0.396322              0.211813
# min         0.000000           0.000000              0.000000
# 25%      1018.000000           0.000000              0.000000
# 50%      1381.000000           0.000000              0.000000
# 75%      3355.000000           0.000000              0.000000
# max      4433.000000           1.000000              1.000000
#
#        IS_FLEET_TOF_MONITORED  IS_CHECKED_IN_VDA  \
# count           861916.000000      861916.000000
# mean                 0.200031           0.344520
# std                  0.400024           0.475212
# min                  0.000000           0.000000
# 25%                  0.000000           0.000000
# 50%                  0.000000           0.000000
# 75%                  0.000000           1.000000
# max                  1.000000           1.000000
#
#        IS_Battery_Supplier_Type2_FAULTY   IS_VIP_FLEET  Battery_Supplier
# count                     861916.000000  861916.000000     836463.000000
# mean                           0.002894       0.042605          1.687913
# std                            0.053714       0.201965          0.928517
# min                            0.000000       0.000000          1.000000
# 25%                            0.000000       0.000000          1.000000
# 50%                            0.000000       0.000000          1.000000
# 75%                            0.000000       0.000000          3.000000
# max                            1.000000       1.000000          4.000000

# %%
df.dtypes
# Out:
# Sample_ID                                 int64
# Charge_mode_DISTANCE                    float64
# SEND_TIME                                object
# Vehicle_ID                                int64
# Operation_TIME                          float64
# Operation_DISTANCE                      float64
# Sender                                    int64
# Gear_Level_Auto_Time                    float64
# Gear_Level_Man_Time                     float64
# Total_Distance                          float64
# Brake_Time                              float64
# Cruise_Time                             float64
# Drive_Distance                          float64
# Drive_Fuel                              float64
# Drive_Time                              float64
# Idle_Fuel                               float64
# Coasting_Time                           float64
# Econ_Time                               float64
# Idle_Time                               float64
# Key_On_Time                             float64
# Pedal_Time                              float64
# measure35                               float64
# measure36                               float64
# measure37                               float64
# measure38                               float64
# measure39                               float64
# measure40                               float64
# measure41                               float64
# measure42                               float64
# measure43                               float64
# measure44                               float64
# measure45                               float64
# measure46                               float64
# measure47                               float64
# measure48                               float64
# measure49                               float64
# Measure_G-1_Time                        float64
# State_Of_Health_Battery                 float64
# Diesel_Mode_Total_Fuel                  float64
# measure50                               float64
# measure51                               float64
# Measure_3                               float64
# Electric_Mode_Time                      float64
# Hybrid_Mode_Time                        float64
# Charge_Mode_Time                        float64
# Diesel_Mode_Time                        float64
# Total_Time                              float64
# Electric_Mode_Distance                  float64
# Hybrid_Mode_Distance                    float64
# Diesel_Mode_Distance                    float64
# Total_Distance__ElectricHybridDiesel    float64
# Battery_Version                           int64
# Battery_Replacement_date                 object
# Battery_Generation                      float64
# Fleet_ID                                float64
# Country                                 float64
# Vehicle_MRK_TYPE                          int64
# EMISSION_LEVEL                            int64
# CURRENT_YEARLY_MILEAGE                    int64
# Measure_2                               float64
# Active_Charge                           float64
# Mounted_Battery_Generation              float64
# Measure_1                               float64
# Measure_R_D                             float64
# Engine_Type                             float64
# Geo_Area                                float64
# City                                    float64
# Cluster                                 float64
# Measure_ROw                               int64
# Is_Bttery_Changed                         int64
# IS_PATTERN_AVAILABLE                      int64
# IS_FLEET_TOF_MONITORED                    int64
# IS_CHECKED_IN_VDA                         int64
# IS_Battery_Supplier_Type2_FAULTY          int64
# IS_VIP_FLEET                              int64
# Battery_Supplier                        float64
# dtype: object

# %% [markdown]
# # Frequently used functions

# %%
def applyPlotPatches(splot):
    for p in splot.patches:
        splot.annotate(format(p.get_height(), '.1f'), 
                       (p.get_x() + p.get_width() / 2., p.get_height()), 
                       ha = 'center', va = 'center', 
                       size=10,
                       xytext = (0, 30), 
                       textcoords = 'offset points',
                       rotation=90)
        
def sns_Settings(title, x_label=None, y_label=None, perc_threshold=None,rotation=0, splot=None):
    plt.title(title)
    plt.ylabel(y_label)
    
    if perc_threshold: plt.axhline(perc_threshold,c="white",lw=3)
    if splot: applyPlotPatches(splot)
    plt.xticks(rotation=rotation)

# %%
df.isna().mean().head()
# Out:
# Sample_ID               0.000000
# Charge_mode_DISTANCE    0.723781
# SEND_TIME               0.001950
# Vehicle_ID              0.000000
# Operation_TIME          0.000117
# dtype: float64

# %% [markdown]
# # Missing values in columns

# %%
# Find threshold for NULL
perc_threshold = 0.99
df_mean_null_temp = df.isna().mean().sort_values()
# print("Mean of null values:", df_mean_null.sort_values())
# TODO group in classes to see number of missing values

plt.figure(figsize=(15,5))
splot = sns.barplot(x=df_mean_null_temp.index, y=df_mean_null_temp.values)
sns_Settings(f"Mean null values", 
             None, 
             "Missing values [%]",
             rotation=90,
            )
plt.show()
del df_mean_null_temp

# %% [markdown]
# # Unique values in each column

# %%
df_temp = df.nunique().sort_values()

# %%
plt.figure(figsize=(20,5))
plt.xticks(rotation=90)

splot=sns.barplot(x=df_temp.index,y=df_temp.values)
sns_Settings(f"Mean null values each Column. Threshold: {perc_threshold*100}%", 
             None, 
             "Missing values",
             perc_threshold=perc_threshold,
             rotation=90,
             splot=splot
            )
del df_temp

# %% [markdown]
# # Distribution of data in columns

# %%
temp_drop_items = ["SEND_TIME","Battery_Replacement_date"]
temp_df = df[[col for col in numerical_list if col not in temp_drop_items]].head()

temp_df=(temp_df-temp_df.mean())/temp_df.std()

temp_df[:10]
# Out:
#    Sample_ID  Charge_mode_DISTANCE  Vehicle_ID  Operation_TIME  \
# 0   1.113492                   NaN         NaN        1.106589
# 1  -0.407151                   NaN         NaN       -0.401830
# 2   1.003137                   NaN         NaN        1.042219
# 3  -1.106653                   NaN         NaN       -0.843437
# 4  -0.602825                   NaN         NaN       -0.903542
#
#    Operation_DISTANCE    Sender  Gear_Level_Auto_Time  Gear_Level_Man_Time  \
# 0            1.365405 -0.447214                   NaN                  NaN
# 1            0.270074 -0.447214                   NaN                  NaN
# 2           -0.072423  1.788854                   NaN                  NaN
# 3           -1.428023 -0.447214                   NaN                  NaN
# 4           -0.135033 -0.447214                   NaN                  NaN
#
#    Total_Distance  Brake_Time  Cruise_Time  Drive_Distance  Drive_Fuel  \
# 0             NaN         NaN          NaN             NaN         NaN
# 1       -0.127823   -0.137562          NaN       -0.134803    1.089553
# 2        1.449145    1.451633          NaN        1.449933         NaN
# 3       -0.587531   -0.584768          NaN       -0.571714   -0.213634
# 4       -0.733791   -0.729303          NaN       -0.743415   -0.875919
#
#    Drive_Time  Idle_Fuel  Coasting_Time  Econ_Time  Idle_Time  Key_On_Time  \
# 0         NaN        NaN            NaN        NaN        NaN          NaN
# 1   -0.151207   0.930046       1.110469   1.129609  -0.232396    -0.162395
# 2    1.454614        NaN            NaN        NaN   1.468395     1.456812
# 3   -0.574895   0.127650      -0.281110  -0.357469  -0.504063    -0.564838
# 4   -0.728513  -1.057696      -0.829359  -0.772140  -0.731935    -0.729579
#
#    Pedal_Time  measure35  measure36  measure37  measure38  measure39  \
# 0         NaN        NaN        NaN        NaN        NaN        NaN
# 1    1.141978        NaN  -0.346167   1.041798        NaN   0.785403
# 2         NaN        NaN        NaN        NaN        NaN        NaN
# 3   -0.422950        NaN   1.127089  -0.089630        NaN  -1.125748
# 4   -0.719027        NaN  -0.780922  -0.952168        NaN   0.340345
#
#    measure40  measure41  measure42  measure43  measure44  measure45  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN   0.790043   1.103628   0.803007   0.796695   0.777061
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3        NaN  -1.124318  -0.845928  -1.120103  -1.122197  -1.128214
# 4        NaN   0.334275  -0.257700   0.317096   0.325502   0.351154
#
#    measure46  measure47  measure48  measure49  Measure_G-1_Time  \
# 0        NaN        NaN        NaN        NaN               NaN
# 1   0.798238        NaN   0.803605   0.817167          1.138082
# 2        NaN        NaN        NaN        NaN               NaN
# 3  -1.121692        NaN  -1.119900  -1.115109         -0.399992
# 4   0.323454        NaN   0.316295   0.297942         -0.738089
#
#    State_Of_Health_Battery  Diesel_Mode_Total_Fuel  measure50  measure51  \
# 0                      NaN                     NaN        NaN        NaN
# 1                -0.738672               -0.192417        NaN        NaN
# 2                      NaN                1.436540        NaN        NaN
# 3                 1.137954               -0.371655        NaN        NaN
# 4                -0.399282               -0.872468        NaN        NaN
#
#    Measure_3  Electric_Mode_Time  Hybrid_Mode_Time  Charge_Mode_Time  \
# 0        NaN                 NaN               NaN               NaN
# 1  -0.299098            0.798238          0.798653          0.817171
# 2   1.471676                 NaN               NaN               NaN
# 3  -0.417113           -1.121692         -1.121556         -1.115108
# 4  -0.755465            0.323454          0.322903          0.297936
#
#    Diesel_Mode_Time  Total_Time  Electric_Mode_Distance  Hybrid_Mode_Distance  \
# 0               NaN         NaN                     NaN                   NaN
# 1          0.776851    0.798683                0.785403              0.790742
# 2               NaN         NaN                     NaN                   NaN
# 3         -1.128275   -1.121546               -1.125748             -1.124100
# 4          0.351424    0.322863                0.340345              0.333358
#
#    Diesel_Mode_Distance  Total_Distance__ElectricHybridDiesel
# 0                   NaN                                   NaN
# 1              1.103628                              0.790528
# 2                   NaN                                   NaN
# 3             -0.845928                             -1.124167
# 4             -0.257700                              0.333639

# %%
fig = plt.figure(figsize=(15,30))
print("Start plotting!")
#sns.boxplot(x="value", y="variable", data=pd.melt(temp_df), ci=None)
sns.boxplot(data=temp_df, orient="h", medianprops={'color':'blue'})
sns_Settings(f"Boxplot of z-score")
# Out:
# Start plotting!

# %% [markdown]
# # Correlation matrix

# %%
corr = df.corr()
fig, ax = plt.subplots(figsize=(20, 15))
mask = np.triu(np.ones_like(corr, dtype=bool))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)
# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap,  center=0,
            square=True, linewidth=0.5,cbar_kws={"shrink": .9})
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Which features is under 5 in sum of correlation

# %%
correlation_min_limit = 5
cond = corr.abs().sum().sort_values()
correlation_min_df = cond.loc[cond > correlation_min_limit]
print(f"Features with less correlation than {5}: {correlation_min_df}")
# Out:
# Features with less correlation than 5: Measure_G-1_Time                         5.633212
# CURRENT_YEARLY_MILEAGE                   6.043931
# Geo_Area                                 6.194948
# Sender                                   6.828086
# IS_FLEET_TOF_MONITORED                   7.322221
# Measure_2                                7.559247
# Vehicle_ID                               8.157503
# Measure_R_D                              8.870240
# Battery_Version                          9.301360
# Measure_1                                9.444233
# Diesel_Mode_Distance                     9.592978
# Country                                 10.036203
# City                                    10.128644
# measure42                               10.265511
# IS_CHECKED_IN_VDA                       10.418386
# Fleet_ID                                10.421482
# Cluster                                 10.508234
# Active_Charge                           11.370702
# measure36                               12.586244
# Is_Bttery_Changed                       12.907105
# Vehicle_MRK_TYPE                        13.746075
# measure49                               13.944358
# Charge_Mode_Time                        14.152629
# Mounted_Battery_Generation              14.487246
# Measure_ROw                             14.717507
# Diesel_Mode_Time                        14.893627
# measure45                               15.208326
# Battery_Generation                      15.367407
# Sample_ID                               15.429130
# measure37                               15.745875
# Battery_Supplier                        15.785537
# Electric_Mode_Distance                  16.029213
# measure39                               16.858436
# State_Of_Health_Battery                 18.016920
# Diesel_Mode_Total_Fuel                  18.137771
# Engine_Type                             18.372602
# EMISSION_LEVEL                          18.415406
# measure51                               18.562403
# measure48                               22.643505
# measure46                               23.038121
# Electric_Mode_Time                      23.275540
# measure50                               23.750356
# measure43                               24.057632
# Idle_Fuel                               25.012830
# measure44                               25.996118
# Measure_3                               27.775796
# Gear_Level_Auto_Time                    28.040356
# Idle_Time                               28.143213
# Drive_Distance                          28.551529
# Total_Distance__ElectricHybridDiesel    28.787165
# Drive_Fuel                              28.858443
# Operation_DISTANCE                      29.030986
# Hybrid_Mode_Distance                    29.042364
# Key_On_Time                             29.176668
# Hybrid_Mode_Time                        29.211325
# measure41                               29.236322
# Total_Time                              29.299757
# Drive_Time                              29.350431
# Total_Distance                          29.741715
# Operation_TIME                          30.312812
# Pedal_Time                              30.348964
# Coasting_Time                           30.588406
# Econ_Time                               31.689360
# dtype: float64

# %%
plt.figure(figsize=(15,10))
plt.xticks(rotation=90)

splot=sns.barplot(x=cond.index,y=cond.values)
sns_Settings(f"Feature with absolute correlation", 
             None, 
             "Missing values [%]",
             rotation=90,
            )

# %% [markdown]
# # Check Timeseries

# %%
df['SEND_TIME'].head()
# Graph for: years, month, days, hours, minutes
sns.bar()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-142-d639e5fc4577> in <module>
#       1 df['SEND_TIME'].head()
#       2 # Graph for: years, month, days, hours, minutes
# ----> 3 sns.bar()
#
# AttributeError: module 'seaborn' has no attribute 'bar'

# %% [markdown]
# # Other

# %%
# Classes?

# Numerical?

# Throwable
Sample_ID

# Too many missing values
